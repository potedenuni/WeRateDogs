# %% [markdown]
# http://docs.tweepy.org/en/latest/api.html#status-methods
#
# https://developer.twitter.com/en/docs/metrics/get-tweet-engagement/overview
#
# https://developer.twitter.com/en/docs/tweets/timelines/overview
#
# https://www.google.com/search?q=python+cast+list+as+array&rlz=1C1CHBD_enUS782US782&oq=python+cast+list+as+array+&aqs=chrome..69i57.6095j0j4&sourceid=chrome&ie=UTF-8
#
# https://stackoverflow.com/questions/2665866/what-does-wb-mean-in-this-code-using-python
#
# https://www.geeksforgeeks.org/reading-writing-text-files-python/
#
# https://docs.python.org/3/library/json.html
#
# https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
#
# https://www.programiz.com/python-programming/variables-datatypes
#
# https://docs.python.org/3/library/datatypes.html
#
# https://www.geeksforgeeks.org/python-pandas-dataframe-info/
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html
#
# https://realpython.com/python-data-types/
#
# https://www.mathworks.com/help/matlab/ref/plot.html
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# https://stackoverflow.com/questions/51565320/suppress-output-in-matplotlib
#
# https://stackoverflow.com/questions/52273543/creating-multiple-boxplots-on-the-same-graph-from-a-dictionary
#
# https://stackoverflow.com/questions/36684013/extract-column-value-based-on-another-column-pandas-dataframe
#
# https://stackoverflow.com/questions/21767900/how-to-move-pandas-data-from-index-to-column-after-multiple-groupby
#
# https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/
#
# https://pythex.org/
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.match.html
#
# https://stackoverflow.com/questions/11266068/python-avoid-new-line-with-print-command
#
# https://stackoverflow.com/questions/192109/is-there-a-built-in-function-to-print-all-the-current-properties-and-values-of-a
#
# https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
#
# https://datascience.stackexchange.com/questions/53676/how-to-delete-a-row-if-a-values-in-a-column-is-not-nan
#
# Top 200 Dog Names json
# https://github.com/sindresorhus/dog-names
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.islower.html
#
# https://stackoverflow.com/questions/21291259/convert-floats-to-ints-in-pandas
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html
#
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
#
# https://stackoverflow.com/questions/237079/how-to-get-file-creation-modification-date-times-in-python
#
# https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py
#
# https://maneeshasane.com/programming/2017/03/subtotals-and-grouping-with-pandas.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
